# %%
import pandas as pd
import numpy as np
df=pd.read_csv('Amazonbookreviews.csv',sep=',')
df
# Out:
#          reviewerID      asin reviewername  helpful  \
# 0    A2SUAM1J3GNN3B   23456.0        SNEHA        2
# 1    A2SUAN1J3GNN0C  879877.0      KARTHII        3
# 2    A2SUAN1J3GNN7B   23456.0     SHASHANK        3
# 3    A5SUAN1J3GNN9B   67578.0        NITIN        3
# 4    A1SUAM1J3GNN3B     123.0      PRANOTI        3
# 5   BA2345WERSDFRER  236789.0      SHALINI        3
# 6   CADERVG3450EREW       NaN       SNEHAL        3
# 7   ASDF345671QWERT  224442.0       SHIKHA        3
# 8     MNHJ879WERFGH   98767.0       AKSHAY        2
# 9    1234ZSDFREQWEG   78761.0       SATISH        2
# 10   9345GHIKLFLLED  321456.0         RAJU        2
# 11              NaN  876231.0        ROHIT        2
# 12   HGKIUYE345SFDG     987.0        MOHIT        2
# 13  NIKRT2398701222     234.0       NILESH        2
# 14   MAHI2348900122     124.0      KAILASH        2
# 15   LIHJKD87634O21     156.0        SONAM        2
# 16  SISISWER4657893     876.0       RAJESH        2
# ...

# %%
df.head()
# Out:
#        reviewerID      asin reviewername  helpful  \
# 0  A2SUAM1J3GNN3B   23456.0        SNEHA        2
# 1  A2SUAN1J3GNN0C  879877.0      KARTHII        3
# 2  A2SUAN1J3GNN7B   23456.0     SHASHANK        3
# 3  A5SUAN1J3GNN9B   67578.0        NITIN        3
# 4  A1SUAM1J3GNN3B     123.0      PRANOTI        3
#
#                                         reviewerText  overallRating  \
# 0  I bought this for my husband who plays the pia...            4.0
# 1                                  good book to read            3.0
# 2                                          high cost            2.5
# 3                                    good useof book            2.2
# 4                            I m happy with the book            3.0
#
#             Summary  UnixreviewTime  reviewTime
# 0       SUBWAY SURF             NaN         NaN
# 1            PILOT              NaN         NaN
# 2   DRIVE IN HEAVEN             NaN         NaN
# 3     SPORTS HEAVEN             NaN         NaN
# ...

# %%
df.tail()
# Out:
#       reviewerID     asin reviewername  helpful           reviewerText  \
# 40   67FDASAA123   2312.0      NANAJJI        3            BYE MY LOVE
# 41     ASWER1234   1222.0       PREETI        2                LOVE U
# 42    QWCVFED123  11111.0        DHONI        2             HELLO DEAR
# 43   123LKIUHNFG   9800.0         MAHI        2  DAER PLEASE READ BOOK
# 44  987DFHGJI657      NaN          DDE        2                   BOOK
#
#     overallRating       Summary  UnixreviewTime  reviewTime
# 40            4.0  HELL OF HELL             NaN         NaN
# 41            4.0          DEAA             NaN         NaN
# 42            4.0   DEAR TO ALL             NaN         NaN
# 43            4.0       MOTHER              NaN         NaN
# 44            4.0  WINE OF WINE             NaN         NaN

# %%
df.shape
# Out:
# (45, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reviewerID      43 non-null     object
#  1   asin            43 non-null     float64
#  2   reviewername    44 non-null     object
#  3   helpful         45 non-null     int64
#  4   reviewerText    45 non-null     object
#  5   overallRating   45 non-null     float64
#  6   Summary         45 non-null     object
#  7   UnixreviewTime  0 non-null      float64
#  8   reviewTime      0 non-null      float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 3.3+ KB

# %%
df.dtypes
# Out:
# reviewerID         object
# asin              float64
# reviewername       object
# helpful             int64
# reviewerText       object
# overallRating     float64
# Summary            object
# UnixreviewTime    float64
# reviewTime        float64
# dtype: object

# %%
df.describe()
# Out:
#                 asin    helpful  overallRating  UnixreviewTime  reviewTime
# count      43.000000  45.000000      45.000000             0.0         0.0
# mean    69702.023256   2.533333       3.282222             NaN         NaN
# std    193175.237815   0.504525       0.816113             NaN         NaN
# min         1.000000   2.000000       2.000000             NaN         NaN
# 25%       140.000000   2.000000       3.000000             NaN         NaN
# 50%      2121.000000   3.000000       3.000000             NaN         NaN
# 75%     22350.500000   3.000000       4.000000             NaN         NaN
# max    879877.000000   3.000000       5.000000             NaN         NaN

# %%
df.isnull().sum()
# Out:
# reviewerID         2
# asin               2
# reviewername       1
# helpful            0
# reviewerText       0
# overallRating      0
# Summary            0
# UnixreviewTime    45
# reviewTime        45
# dtype: int64

# %%
df = df.dropna(axis=1) 
df
# Out:
#     helpful                                       reviewerText  overallRating  \
# 0         2  I bought this for my husband who plays the pia...            4.0
# 1         3                                  good book to read            3.0
# 2         3                                          high cost            2.5
# 3         3                                    good useof book            2.2
# 4         3                            I m happy with the book            3.0
# 5         3             im not happy with the delay of product            3.0
# 6         3                                      delay in book            3.0
# 7         3                                     Wonderful book            3.0
# 8         2  The music is at times hard to read because we ...            3.0
# 9         2                                        many errors            5.0
# 10        2                                            no mini            4.0
# ...

# %%
df1=df[['helpful','reviewerText','overallRating']].loc[0:15]
df1
# Out:
#     helpful                                       reviewerText  overallRating
# 0         2  I bought this for my husband who plays the pia...            4.0
# 1         3                                  good book to read            3.0
# 2         3                                          high cost            2.5
# 3         3                                    good useof book            2.2
# 4         3                            I m happy with the book            3.0
# 5         3             im not happy with the delay of product            3.0
# 6         3                                      delay in book            3.0
# 7         3                                     Wonderful book            3.0
# 8         2  The music is at times hard to read because we ...            3.0
# 9         2                                        many errors            5.0
# 10        2                                            no mini            4.0
# ...

# %%
df2=df[['helpful','reviewerText','overallRating']].loc[16:30]
df2
# Out:
#     helpful        reviewerText  overallRating
# 16        2       money is dis             3.0
# 17        2    stare the raeder            2.0
# 18        2     reader is giood            2.0
# 19        2             faskjas            2.0
# 20        2               fdghi            2.0
# 21        2           dvdasaewb            4.0
# 22        2                 NA             4.0
# 23        2                 NA             4.0
# 24        3                 NA             4.0
# 25        3         0.888888888            4.0
# 26        3         9.666666667            4.0
# 27        3             helpful            4.0
# 28        3       staff is good            4.0
# 29        3  good buy for money            4.0
# 30        3       money is dis             4.0

# %%
df3=df[['helpful','reviewerText','overallRating']].loc[31:44]
df3
# Out:
#     helpful           reviewerText  overallRating
# 31        3       stare the raeder            4.0
# 32        3        reader is giood            3.0
# 33        3                faskjas            3.0
# 34        3                  fdghi            3.0
# 35        3               8.78E+21            3.0
# 36        3                  67667            2.0
# 37        3                3434567            2.0
# 38        3                   098O            2.0
# 39        3              GOOD LUCK            2.0
# 40        3            BYE MY LOVE            4.0
# 41        2                LOVE U             4.0
# 42        2             HELLO DEAR            4.0
# 43        2  DAER PLEASE READ BOOK            4.0
# 44        2                   BOOK            4.0

# %%
merge=pd.concat([df1,df2,df3])
merge
# Out:
#     helpful                                       reviewerText  overallRating
# 0         2  I bought this for my husband who plays the pia...            4.0
# 1         3                                  good book to read            3.0
# 2         3                                          high cost            2.5
# 3         3                                    good useof book            2.2
# 4         3                            I m happy with the book            3.0
# 5         3             im not happy with the delay of product            3.0
# 6         3                                      delay in book            3.0
# 7         3                                     Wonderful book            3.0
# 8         2  The music is at times hard to read because we ...            3.0
# 9         2                                        many errors            5.0
# 10        2                                            no mini            4.0
# ...

# %%
sort_values=df.sort_values('overallRating',ascending=False)
sort_values
# Out:
#     helpful                                       reviewerText  overallRating  \
# 9         2                                        many errors            5.0
# 0         2  I bought this for my husband who plays the pia...            4.0
# 21        2                                          dvdasaewb            4.0
# 43        2                              DAER PLEASE READ BOOK            4.0
# 42        2                                         HELLO DEAR            4.0
# 41        2                                            LOVE U             4.0
# 40        3                                        BYE MY LOVE            4.0
# 31        3                                   stare the raeder            4.0
# 30        3                                      money is dis             4.0
# 29        3                                 good buy for money            4.0
# 28        3                                      staff is good            4.0
# ...

# %%
trans=df.transpose()
trans
# Out:
#                                                               0   \
# helpful                                                        2
# reviewerText   I bought this for my husband who plays the pia...
# overallRating                                                4.0
# Summary                                              SUBWAY SURF
#
#                               1                2                3   \
# helpful                        3                3                3
# reviewerText   good book to read        high cost  good useof book
# overallRating                3.0              2.5              2.2
# Summary                   PILOT   DRIVE IN HEAVEN    SPORTS HEAVEN
#
#                                     4   \
# helpful                              3
# reviewerText   I m happy with the book
# overallRating                      3.0
# Summary               HEAVEN OF PEARLS
#
#                                                    5              6   \
# ...

# %%
shape=df.shape
shape
# Out:
# (45, 4)

# %%
pivot_table=pd.pivot_table(df,index=['overallRating','Summary'],values='helpful')
pivot_table
# Out:
#                                      helpful
# overallRating Summary
# 2.0           INDIA IS MY COUNTRY        2.0
#               MOTHER                     2.0
#               ONE FOR ALLL               2.0
#               WINE OF WINE               2.0
#               faskjas                    3.0
#               money is dis               3.0
#               reader is giood            3.0
#               stare the raeder           3.0
# 2.2           SPORTS HEAVEN              3.0
# 2.5           DRIVE IN HEAVEN            3.0
# 3.0           DARK KNIGHT                2.0
#               DEAA                       2.0
#               DEAR TO ALL                2.0
#               GODESS LIFE                3.0
#               GODS GIFT                  3.0
#               HEAVEN OF PEARLS           3.0
#               HELL OF HELL               2.0
#               INDIA A MASSIVE POWER      2.0
#               LIFE OF PIE                3.0
# ...

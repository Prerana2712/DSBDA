# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('heart.csv')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
plt.figure(figsize=(10,4))
sns.boxplot(x=df.target,y=df.age,data=df)
plt.xlabel('target')
plt.ylabel('age')
plt.title('Age vs target')
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.histplot(df['chol'],bins=10,kde=True)
plt.xlabel('Cholestrol')
plt.ylabel('Frequency')
plt.title('histo of chol')
plt.show()

# %%
plt.figure(figsize=(15,9))
plt.plot(df['age'])
plt.xlabel('Index')
plt.ylabel('Age')
plt.title('Resting BP vs Age')
plt.show()

# %%
plt.figure(figsize=(15,9))
sns.lineplot(data=df,x=df['age'],y=df['fbs'])
plt.xlabel('Index')
plt.ylabel('Age')
plt.title('Resting BP vs Age')
plt.show()

# %%
plt.figure(figsize=(15,9))
sns.lineplot(data=df,x=df['age'],y=df['chol'],hue='target')
plt.xlabel('Age')
plt.ylabel('chol')
plt.title('Resting BP vs Age')
plt.show()

# %%
sns.lineplot(data=df[['chol','thal']])
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize=(20,15))
pd.crosstab(df.age,df.target).plot(kind='bar')
plt.xlabel('age')
plt.ylabel('cholestrol')
plt.title('Age vs cholestrol')
plt.show()

# %%
sns.countplot(data=df,x=df['target'])
# Out:
# <AxesSubplot: xlabel='target', ylabel='count'>

# %%
labels=["Disease","No Disease"]

disease_c=df[df['target']==0].shape[0]

# %%
 no_disease_c=df[df['target']==1].shape[0]
count=[disease_c,no_disease_c]

# %%
plt.figure(figsize=(9,9))
plt.pie(count,labels=labels,autopct='%1.1f%%',startangle=90)
plt.show()

# %%
plt.figure(figsize=(15,9))
plt.scatter(df['age'],df['chol'])
plt.xlabel('Index')
plt.ylabel('Age')
plt.title('Resting BP vs Age')
plt.show()

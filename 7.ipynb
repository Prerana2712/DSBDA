# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('AirQualityUCI.csv')
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10-03-2004  18:00:00     2.6       1360.0     150.0      11.9
# 1     10-03-2004  19:00:00     2.0       1292.0     112.0       9.4
# 2     10-03-2004  20:00:00     2.2       1402.0      88.0       9.0
# 3     10-03-2004  21:00:00     2.2       1376.0      80.0       9.2
# 4     10-03-2004  22:00:00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9466         NaN       NaN     NaN          NaN       NaN       NaN
# 9467         NaN       NaN     NaN          NaN       NaN       NaN
# 9468         NaN       NaN     NaN          NaN       NaN       NaN
# 9469         NaN       NaN     NaN          NaN       NaN       NaN
# 9470         NaN       NaN     NaN          NaN       NaN       NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10-03-2004  18:00:00     2.6       1360.0     150.0      11.9
# 1     10-03-2004  19:00:00     2.0       1292.0     112.0       9.4
# 2     10-03-2004  20:00:00     2.2       1402.0      88.0       9.0
# 3     10-03-2004  21:00:00     2.2       1376.0      80.0       9.2
# 4     10-03-2004  22:00:00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9466         NaN       NaN     NaN          NaN       NaN       NaN
# 9467         NaN       NaN     NaN          NaN       NaN       NaN
# 9468         NaN       NaN     NaN          NaN       NaN       NaN
# 9469         NaN       NaN     NaN          NaN       NaN       NaN
# 9470         NaN       NaN     NaN          NaN       NaN       NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
df1=df.loc[0:25]

# %%
df1
# Out:
#           Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0   10-03-2004  18:00:00     2.6       1360.0     150.0      11.9
# 1   10-03-2004  19:00:00     2.0       1292.0     112.0       9.4
# 2   10-03-2004  20:00:00     2.2       1402.0      88.0       9.0
# 3   10-03-2004  21:00:00     2.2       1376.0      80.0       9.2
# 4   10-03-2004  22:00:00     1.6       1272.0      51.0       6.5
# 5   10-03-2004  23:00:00     1.2       1197.0      38.0       4.7
# 6   11-03-2004  00:00:00     1.2       1185.0      31.0       3.6
# 7   11-03-2004  01:00:00     1.0       1136.0      31.0       3.3
# 8   11-03-2004  02:00:00     0.9       1094.0      24.0       2.3
# 9   11-03-2004  03:00:00     0.6       1010.0      19.0       1.7
# 10  11-03-2004  04:00:00  -200.0       1011.0      14.0       1.3
# 11  11-03-2004  05:00:00     0.7       1066.0       8.0       1.1
# 12  11-03-2004  06:00:00     0.7       1052.0      16.0       1.6
# ...

# %%
plt.figure(figsize=(15,9))
sns.boxplot(data=df1,x=df1['Time'],y=df1['T'])
plt.xlabel("COgt")
plt.ylabel("T")
plt.title("Co vs T")
plt.show()

# %%
plt.figure(figsize=(15,9))
sns.histplot(df['NOx(GT)'],kde=True,bins=10)
plt.xlabel("COgt")
plt.ylabel("T")
plt.title("Co vs T")
plt.show()

# %%
plt.figure(figsize=(15,9))
sns.lineplot(data=df,x=df['RH'],y=df['AH'])
plt.xlabel("COgt")
plt.ylabel("T")
plt.title("Co vs T")
plt.show()

# %%
plt.figure(figsize=(15,9))
sns.lineplot(data=df1,x=df1['Time'],y=df1['T'])
plt.xlabel("COgt")
plt.ylabel("T")
plt.title("Co vs T")
plt.show()

# %%
plt.figure(figsize=(15,9))
sns.lineplot(data=df1,x=df1['T'],y=df1['AH'],hue='C6H6(GT)')
plt.xlabel("COgt")
plt.ylabel("T")
plt.title("Co vs T")
plt.show()

# %%
df1.nunique()
# Out:
# Date              2
# Time             24
# CO(GT)           17
# PT08.S1(CO)      25
# NMHC(GT)         24
# C6H6(GT)         26
# PT08.S2(NMHC)    26
# NOx(GT)          24
# PT08.S3(NOx)     26
# NO2(GT)          24
# PT08.S4(NO2)     25
# PT08.S5(O3)      25
# T                17
# RH               24
# AH               26
# Unnamed: 15       0
# Unnamed: 16       0
# dtype: int64

# %%
plt.figure(figsize=(20,32))
#pd.crosstab(df1['Date'],df1['CO(GT)']).plot(kind="bar")
sns.barplot(x=df1['NOx(GT)'],y=df1['NMHC(GT)'],data=df)
plt.xlabel("COgt")
plt.ylabel("T")
plt.title("Co vs T")
plt.show()

# %%
plt.figure(figsize=(20,32))
#pd.crosstab(df1['Date'],df1['CO(GT)']).plot(kind="bar")
plt.scatter(df1['NOx(GT)'],df1['NMHC(GT)'])
plt.xlabel("COgt")
plt.ylabel("T")
plt.title("Co vs T")
plt.show()

# %%
sns.countplot(data=df1,x=df1['Date'])
# Out:
# <AxesSubplot: xlabel='Date', ylabel='count'>

# %%
labels=['CO','NO2','SO2']
sizes=[25,45,50]
plt.figure(figsize=(15,9))
plt.pie(sizes,labels=labels,autopct='%1.1f%%')
plt.show()
